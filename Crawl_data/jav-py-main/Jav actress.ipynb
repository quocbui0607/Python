# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_json('acctress.json')
data
# Out:
#           id             name   japanName         hiragana  bust  waist   hip  \
# 0          3     Kitagawa Yui        北川ゆい           きたがわゆい  95.0   60.0  88.0
# 1          4            Akira       Akira              あきら  90.0   58.0  86.0
# 2          6           Cocolo      COCOLO              こころ  96.0   55.0  85.0
# 3          8            Saiko       Saiko              さいこ  80.0   59.0  82.0
# 4         11        Aida Momo       あいだもも            あいだもも  82.0   55.0  89.0
# ...      ...              ...         ...              ...   ...    ...   ...
# 11181  10538    Tomita Sayaka       富田さやか           とみたさやか  80.0   60.0  83.0
# 11182  10540    Mizimoto Miwa        藤本美羽           ふじもとみわ  88.0   58.0  87.0
# 11183  10542  Nakahara Risako       中原りさこ          なかはらりさこ  84.0   59.0  86.0
# 11184  10544   Sugimoto Ayako  希崎圭蓮（杉本彩子）  きさきかれん（すぎもとあやこ）  90.0   63.0  87.0
# 11185  10550     Akatuki Runa        紅月ルナ           あかつきるな  88.0   59.0  86.0
#
# ...

# %%
data[data['name']=='Morimoto Tugumi']
# Out:
#            id             name japanName hiragana  bust  waist   hip  height  \
# 9366  1051751  Morimoto Tugumi     森本つぐみ  もりもとつぐみ  90.0   60.0  90.0   152.0
#
#         birthday blood_type        hobby prefectures
# 9366  1999-08-07       None  カラオケ、アイドル鑑賞        None

# %%
data[data['name']=='Mita An']
# Out:
#            id     name   japanName      hiragana  bust  waist   hip  height  \
# 8723  1042465  Mita An  川田みはる（三田杏）  かわだみはる（みたあん）  84.0   59.0  87.0   166.0
#
#         birthday blood_type      hobby prefectures
# 8723  1999-02-16       None  犬と遊ぶこと、料理         青森県

# %%
data[data['name']=='Yukimi Chinatsu']
# Out:
#            id             name japanName hiragana  bust  waist   hip  height  \
# 9229  1048856  Yukimi Chinatsu      雪美千夏   ゆきみちなつ  90.0   59.0  86.0   157.0
#
#         birthday blood_type hobby prefectures
# 9229  1999-07-30       None  None         東京都
